# %% [markdown]
# # Machine Learning Internship by Aspiration.ai

# %% [markdown]
# # Module 2

# %% [markdown]
# ### Problem 2.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('week2.csv')
df.head()
# Out:
#    Unnamed: 0 Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0           0    ITC     EQ  2017-05-15      274.95      275.90      278.90
# 1           1    ITC     EQ  2017-05-16      277.95      278.50      284.30
# 2           2    ITC     EQ  2017-05-17      283.45      284.10      284.40
# 3           3    ITC     EQ  2017-05-18      281.65      278.00      281.05
# 4           4    ITC     EQ  2017-05-19      277.90      282.25      295.65
#
#    Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0     275.50      278.50       277.95  ...                5462855
# 1     278.00      283.00       283.45  ...               11204308
# 2     279.25      281.50       281.65  ...                8297700
# 3     277.05      277.65       277.90  ...                7924261
# 4     281.95      286.40       286.20  ...               35724128
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# Month                       int64
# Year                        int64
# VWAP                      float64
# Day_Perc_Change           float64
# Trend                      object
# dtype: object

# %%
df['Date'] = df['Date'].astype('datetime64')

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total Traded Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty           float64
# Month                              int64
# Year                               int64
# VWAP                             float64
# Day_Perc_Change                  float64
# Trend                             object
# dtype: object

# %%
df.set_index('Date', inplace=True)

# %%
plt.figure(figsize = (16,8))
plt.plot(df['Close Price'],linewidth = 1,label="Close Price")
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Date vs Close Price')

plt.legend()
plt.show()

# %% [markdown]
# ### All IndiaNDTV Profit Team : Updated: July 18, 2017 03:49 pm IST
# ### ITC Share Price Plunges 15%, Investors Lose Nearly Rs 60,000 Crore
# * ITC shares fell to Rs 276.90 on the Bombay Stock Exchange, which reduced its market value to Rs 3.37 lakh crore.
# <p>  ITC's share price plunged as much as 15 per cent on Tuesday, wiping out nearly Rs 60,000 crore of investor's wealth after the <b>GST Council increased compensation cess on cigarettes</b>. </p>

# %% [markdown]
# ### Problem 2.2

# %%
plt.figure(figsize = (16,8))
plt.stem(df.index, df['Day_Perc_Change'],label = "Day_Perc_Change")
plt.xlabel('Date')
plt.ylabel('Daily percentage change in stock value')
plt.title('Date vs Day_Perc_Change')

plt.legend()
plt.show()
# Out:
# <ipython-input-8-ceed4f6c1ab6>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(df.index, df['Day_Perc_Change'],label = "Day_Perc_Change")

# %% [markdown]
# ### Problem 2.3

# %%
plt.figure(figsize = (16,8))
plt.plot(df['Total Traded Quantity'],linewidth = 1,label = "Total Traded Quantity")
plt.xlabel('Date')
plt.ylabel('Total Traded Quantity')
plt.title('Date vs Total Traded Quantity')

plt.legend()
plt.show()

# %% [markdown]
# ### Problem 2.4

# %%
df_trends = df.groupby('Trend')['Trend'].count()
df_trends
# Out:
# Trend
# Slight or No change    494
# Name: Trend, dtype: int64

# %%
plt.figure(figsize = (10,5))
plt.pie(df_trends,autopct='%1.1f%%')

plt.axis('equal')
plt.title("Type of Trends")
plt.legend(labels = df_trends.index, loc = 'upper right')
plt.show()

# %%
mean_by_trend = df.groupby('Trend', as_index=False)['Total Traded Quantity'].mean()
median_by_trend = df.groupby('Trend', as_index=False)['Total Traded Quantity'].median()

fig, splot = plt.subplots(figsize = (16,5),nrows=1,ncols=2)

splot[0].bar(mean_by_trend['Trend'], mean_by_trend['Total Traded Quantity'], color = 'blue')
splot[0].set_title("Mean of Volume Trendwise")
splot[0].set_xlabel("Type of Trends")
splot[0].set_ylabel("Total Traded Quantity")

splot[1].bar(median_by_trend['Trend'], median_by_trend['Total Traded Quantity'], color = 'red')
splot[1].set_title("Median of Volume Trendwise")
splot[1].set_xlabel("Type of Trends")
splot[1].set_ylabel("Total Traded Quantity")
# Out:
# Text(0, 0.5, 'Total Traded Quantity')

# %% [markdown]
# ### Problem 2.5

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Symbol', 'Series', 'Prev Close', 'Open Price',
#        'High Price', 'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty', 'Month', 'Year', 'VWAP', 'Day_Perc_Change',
#        'Trend'],
#       dtype='object')

# %%
count,bin_edges = np.histogram(df['Day_Perc_Change'],bins = 10)
print(count,bin_edges)

plt.figure(figsize = (16,8))
plt.hist(df['Day_Perc_Change'], 10, label = 'Day_Perc_Change frequency', rwidth= 0.9, color = 'green')
plt.xlabel('Day_Perc_Change')
plt.ylabel('frequency')
plt.title("Day_Perc_Change distribution")

plt.xticks(bin_edges)
plt.legend()
plt.show()
# Out:
# [  1   0   0   0   3  48 288 134  17   3] [-0.12486545 -0.10629924 -0.08773303 -0.06916682 -0.05060061 -0.0320344
#  -0.01346819  0.00509802  0.02366423  0.04223044  0.06079665]

# %% [markdown]
# ### Problem 2.6

# %%
df1 = pd.read_csv('BAJFINANCE.csv')
df2 = pd.read_csv('HDFCBANK.csv')
df3 = pd.read_csv('HINDUNILVR.csv')
df4 = pd.read_csv('RELIANCE.csv')
df5 = pd.read_csv('TCS.csv')

# %%
df1.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  BAJFINANCE     EQ  15-May-2017     1314.75      1323.0      1348.5
# 1  BAJFINANCE     EQ  16-May-2017     1332.95      1337.4      1358.8
# 2  BAJFINANCE     EQ  17-May-2017     1347.75      1350.0      1374.0
# 3  BAJFINANCE     EQ  18-May-2017     1324.80      1299.0      1343.0
# 4  BAJFINANCE     EQ  19-May-2017     1314.55      1324.0      1333.9
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1317.65      1332.0      1332.95        1335.96                 634195
# 1    1327.20      1346.0      1347.75        1344.96                 788530
# 2    1297.50      1320.0      1324.80        1343.51                2408302
# 3    1296.05      1310.7      1314.55        1325.97                1210985
# 4    1265.55      1288.0      1289.15        1295.81                1167010
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df2.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  HDFCBANK     EQ  15-May-2017     1551.65      1550.0      1557.2
# 1  HDFCBANK     IL  15-May-2017     1567.00      1583.0      1583.0
# 2  HDFCBANK     EQ  16-May-2017     1553.40      1555.0      1562.0
# 3  HDFCBANK     EQ  17-May-2017     1559.65      1558.8      1565.4
# 4  HDFCBANK     IL  17-May-2017     1583.00      1600.0      1600.0
#
#    Low Price      Last Price  Close Price  Average Price  \
# 0    1542.25         1553.00      1553.40        1550.73
# 1    1583.00               -      1583.00        1583.00
# 2    1548.25         1561.85      1559.65        1555.11
# 3    1551.50         1557.50      1557.15        1557.51
# 4    1600.00               -      1600.00        1600.00
#
#    Total Traded Quantity      Turnover  No. of Trades  Deliverable Qty  \
# 0                 701195  1.087368e+09          15104           309282
# ...

# %%
df3.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  HINDUNILVR     EQ  15-May-2017      980.20       981.3      988.85
# 1  HINDUNILVR     EQ  16-May-2017      983.25       983.0     1002.50
# 2  HINDUNILVR     EQ  17-May-2017     1000.40      1004.0     1012.00
# 3  HINDUNILVR     EQ  18-May-2017     1009.40      1008.0     1009.00
# 4  HINDUNILVR     EQ  19-May-2017      990.25      1000.0     1022.75
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     974.55       982.5       983.25         980.72                 734446
# 1     982.05       999.5      1000.40         994.00                1503815
# 2     991.10      1009.0      1009.40        1003.84                1999387
# 3     983.00       987.5       990.25         997.56                2690943
# 4    1000.00      1004.1      1008.00        1009.97                3059815
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df4.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  RELIANCE     EQ  15-May-2017     1350.45     1356.40     1356.40
# 1  RELIANCE     EQ  16-May-2017     1344.10     1346.05     1376.90
# 2  RELIANCE     EQ  17-May-2017     1356.30     1353.00     1365.95
# 3  RELIANCE     EQ  18-May-2017     1353.10     1340.25     1350.00
# 4  RELIANCE     EQ  19-May-2017     1327.35     1333.00     1335.70
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0    1333.50     1343.60      1344.10        1344.22                1540213
# 1    1341.00     1356.20      1356.30        1360.59                2892947
# 2    1347.75     1350.00      1353.10        1354.16                2250304
# 3    1324.10     1327.45      1327.35        1336.14                2237916
# 4    1310.00     1318.20      1318.85        1321.99                2928883
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
df5.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TCS     EQ  15-May-2017     2360.65      2375.1     2377.95    2341.60
# 1    TCS     EQ  16-May-2017     2365.10      2380.0     2435.00    2373.45
# 2    TCS     EQ  17-May-2017     2429.15      2433.5     2460.75    2423.00
# 3    TCS     EQ  18-May-2017     2455.35      2450.0     2572.00    2442.25
# 4    TCS     EQ  19-May-2017     2536.20      2536.2     2540.55    2486.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     2368.00      2365.10        2352.60                 908802
# 1     2425.10      2429.15        2410.26                1800513
# 2     2450.00      2455.35        2443.31                1438099
# 3     2525.00      2536.20        2525.78                2569297
# 4     2503.85      2507.15        2506.58                 893022
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
close_prices_df = pd.DataFrame()

for dfs in [df1,df2,df3,df4,df5]:
    dfs['Series'] = dfs['Series'][dfs['Series'] == 'EQ']
    close_prices_df[dfs.iloc[0,0]] = dfs['Close Price']

close_prices_df['Date'] = df1['Date'].astype('Datetime64')
close_prices_df.set_index('Date', inplace = True)
close_prices_df.head()
# Out:
#             BAJFINANCE  HDFCBANK  HINDUNILVR  RELIANCE      TCS
# Date
# 2017-05-15     1332.95   1553.40      983.25   1344.10  2365.10
# 2017-05-16     1347.75   1583.00     1000.40   1356.30  2429.15
# 2017-05-17     1324.80   1559.65     1009.40   1353.10  2455.35
# 2017-05-18     1314.55   1557.15      990.25   1327.35  2536.20
# 2017-05-19     1289.15   1600.00     1008.00   1318.85  2507.15

# %%
close_prices_df = close_prices_df.pct_change().dropna()
close_prices_df
# Out:
#             BAJFINANCE  HDFCBANK  HINDUNILVR  RELIANCE       TCS
# Date
# 2017-05-16    0.011103  0.019055    0.017442  0.009077  0.027081
# 2017-05-17   -0.017028 -0.014750    0.008996 -0.002359  0.010786
# 2017-05-18   -0.007737 -0.001603   -0.018972 -0.019030  0.032928
# 2017-05-19   -0.019322  0.027518    0.017925 -0.006404 -0.011454
# 2017-05-22   -0.036458 -0.026813    0.010516  0.004019  0.009652
# ...                ...       ...         ...       ...       ...
# 2019-05-07   -0.005685  0.014758    0.017137 -0.029894 -0.019886
# 2019-05-08   -0.031736  0.004790   -0.005184 -0.032787 -0.037646
# 2019-05-09    0.017133 -0.000720    0.008912 -0.033091  0.012125
# 2019-05-10   -0.016323  0.003131   -0.009567 -0.004218 -0.002734
# 2019-05-13    0.003079 -0.006563    0.008622 -0.015266  0.000418
#
# [494 rows x 5 columns]

# %%
#plt.figure(figsize = (15,15))
sns.pairplot(close_prices_df)

# %%
plt.figure(figsize=(20,10))

sns.heatmap(close_prices_df.corr(), annot=True, cmap='gist_yarg')

plt.show()

# %% [markdown]
# ### Problem 2.7

# %%
close_prices_df = close_prices_df.rolling(7).std().dropna()
close_prices_df
# Out:
#             BAJFINANCE  HDFCBANK  HINDUNILVR  RELIANCE       TCS
# Date
# 2017-05-24    0.014581  0.023133    0.012585  0.009731  0.015697
# 2017-05-25    0.019637  0.022354    0.011859  0.008575  0.015455
# 2017-05-26    0.028437  0.021475    0.012172  0.015081  0.018936
# 2017-05-29    0.028442  0.021572    0.010417  0.013914  0.015261
# 2017-05-30    0.027365  0.018882    0.010721  0.013299  0.014852
# ...                ...       ...         ...       ...       ...
# 2019-05-07    0.011430  0.010471    0.014430  0.015736  0.012842
# 2019-05-08    0.015657  0.010451    0.014197  0.018961  0.020369
# 2019-05-09    0.017778  0.009693    0.014381  0.018130  0.021011
# 2019-05-10    0.017988  0.006174    0.013870  0.017632  0.020242
# 2019-05-13    0.016685  0.008047    0.013291  0.014219  0.020037
#
# [488 rows x 5 columns]

# %%
close_prices_df['TCS'].plot(figsize = (16,8), color = 'blue')

plt.legend()
plt.xlabel('Date')
plt.ylabel('Square Root of Variance')
plt.show()

# %% [markdown]
# ### Problem 2.8

# %%
df6 = pd.read_csv('Nifty50.csv')
df6.head()
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77

# %%
df6.dtypes
# Out:
# Date                  object
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Shares Traded          int64
# Turnover (Rs. Cr)    float64
# dtype: object

# %%
df6['Date'] = df6['Date'].astype('Datetime64')
df6.set_index('Date', inplace=True)
df6.head()
# Out:
#                Open     High      Low    Close  Shares Traded  \
# Date
# 2017-05-15  9433.55  9449.25  9423.10  9445.40      145163953
# 2017-05-16  9461.00  9517.20  9456.35  9512.25      171709433
# 2017-05-17  9517.60  9532.60  9486.10  9525.75      211856040
# 2017-05-18  9453.20  9489.10  9418.10  9429.45      199340647
# 2017-05-19  9469.90  9505.75  9390.75  9427.90      259861396
#
#             Turnover (Rs. Cr)
# Date
# 2017-05-15            7790.97
# 2017-05-16            9209.89
# 2017-05-17           10726.23
# 2017-05-18           10782.46
# 2017-05-19           11544.77

# %%
df6 = df6[['Close']]
df6.rename(columns = {'Close' : 'Nifty50'}, inplace= True)
df6.head()
# Out:
#             Nifty50
# Date
# 2017-05-15  9445.40
# 2017-05-16  9512.25
# 2017-05-17  9525.75
# 2017-05-18  9429.45
# 2017-05-19  9427.90

# %%
df6 = df6.pct_change().dropna().rolling(7).std().dropna()
df6
# Out:
#              Nifty50
# Date
# 2017-05-24  0.005509
# 2017-05-25  0.008139
# 2017-05-26  0.008831
# 2017-05-29  0.007363
# 2017-05-30  0.007268
# ...              ...
# 2019-05-07  0.006664
# 2019-05-08  0.007408
# 2019-05-09  0.004605
# 2019-05-10  0.004363
# 2019-05-13  0.004474
#
# [487 rows x 1 columns]

# %%
df6.plot(figsize = (16,8), color = 'blue')
close_prices_df['TCS'].plot(figsize = (16,8), color = 'magenta')

plt.legend()

plt.xlabel('Date')
plt.ylabel('Square Root of Variance')
plt.show()

# %%
close_prices_df
# Out:
#             BAJFINANCE  HDFCBANK  HINDUNILVR  RELIANCE       TCS
# Date
# 2017-05-24    0.014581  0.023133    0.012585  0.009731  0.015697
# 2017-05-25    0.019637  0.022354    0.011859  0.008575  0.015455
# 2017-05-26    0.028437  0.021475    0.012172  0.015081  0.018936
# 2017-05-29    0.028442  0.021572    0.010417  0.013914  0.015261
# 2017-05-30    0.027365  0.018882    0.010721  0.013299  0.014852
# ...                ...       ...         ...       ...       ...
# 2019-05-07    0.011430  0.010471    0.014430  0.015736  0.012842
# 2019-05-08    0.015657  0.010451    0.014197  0.018961  0.020369
# 2019-05-09    0.017778  0.009693    0.014381  0.018130  0.021011
# 2019-05-10    0.017988  0.006174    0.013870  0.017632  0.020242
# 2019-05-13    0.016685  0.008047    0.013291  0.014219  0.020037
#
# [488 rows x 5 columns]

# %%
ax = close_prices_df.plot(figsize = (16,8), color = ['blue', 'green', 'magenta', 'black', 'cyan'])
ax.plot(df6,label = 'Nifty50',color = 'red')

plt.legend()
plt.show()

# %% [markdown]
# ### Problem 2.9

# %%
df['21_day_SMA'] = df['Close Price'].rolling(21).mean()
df['34_day_SMA'] = df['Close Price'].rolling(34).mean()
df
# Out:
#             Unnamed: 0 Symbol Series  Prev Close  Open Price  High Price  \
# Date
# 2017-05-15           0    ITC     EQ      274.95      275.90      278.90
# 2017-05-16           1    ITC     EQ      277.95      278.50      284.30
# 2017-05-17           2    ITC     EQ      283.45      284.10      284.40
# 2017-05-18           3    ITC     EQ      281.65      278.00      281.05
# 2017-05-19           4    ITC     EQ      277.90      282.25      295.65
# ...                ...    ...    ...         ...         ...         ...
# 2019-05-07         491    ITC     EQ      307.00      308.25      309.50
# 2019-05-08         492    ITC     EQ      301.90      300.00      303.40
# 2019-05-09         493    ITC     EQ      300.65      299.40      301.30
# 2019-05-10         494    ITC     EQ      299.85      300.00      300.45
# 2019-05-13         495    ITC     EQ      297.75      295.10      303.50
#
#             Low Price  Last Price  Close Price  Average Price  ...  \
# ...

# %%
df[['21_day_SMA', '34_day_SMA']].plot(figsize= (16,8))

plt.xlabel('Date')
plt.ylabel('Average Price')
plt.legend()
plt.show()

# %%
df['Trade_Call'] = 0
for index, column in df.iterrows():
    if column['21_day_SMA'] != np.nan and column['34_day_SMA'] != np.nan:    
        if column['21_day_SMA'] < column['34_day_SMA']:
            df.at[index, 'Trade_Call'] = 0
        elif column['21_day_SMA'] > column['34_day_SMA']:
            df.at[index, 'Trade_Call'] = 1
        else:
            df.at[index, 'Trade_Call'] = 0
            
df['Trade_Call_Change'] = df['Trade_Call'].diff()

# %%
df['Trade_Call'].value_counts()
# Out:
# 0    267
# 1    227
# Name: Trade_Call, dtype: int64

# %%
ax = df[['Close Price','21_day_SMA', '34_day_SMA']].plot(figsize= (16,8), color = ['black', 'blue', 'magenta'])


ax.plot(df['21_day_SMA'][df['Trade_Call_Change'] == -1].index,
        df['21_day_SMA'][df['Trade_Call_Change'] == -1], 'v', markersize=15, color = 'red', label = 'SELL')
ax.plot(df['21_day_SMA'][df['Trade_Call_Change'] == 1].index,
        df['21_day_SMA'][df['Trade_Call_Change'] == 1], '^', markersize=15, color = 'green', label= 'BUY')


plt.title('Trade Calls based on SMA of 21days and 34days')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.legend()
plt.show()

# %% [markdown]
# ### Problem 2.10

# %%
df["14_day_SMA"] = df['Close Price'].rolling(14).mean()
df["14_day_STD"] = df['Close Price'].rolling(14).std()
df["14_day_bollinger_upper"] = df["14_day_SMA"] + df["14_day_STD"] * 2
df["14_day_bollinger_lower"] = df["14_day_SMA"] - df["14_day_STD"] * 2
df.reset_index(inplace=True)

df.tail()
# Out:
#           Date  Unnamed: 0 Symbol Series  Prev Close  Open Price  High Price  \
# 489 2019-05-07         491    ITC     EQ      307.00      308.25      309.50
# 490 2019-05-08         492    ITC     EQ      301.90      300.00      303.40
# 491 2019-05-09         493    ITC     EQ      300.65      299.40      301.30
# 492 2019-05-10         494    ITC     EQ      299.85      300.00      300.45
# 493 2019-05-13         495    ITC     EQ      297.75      295.10      303.50
#
#      Low Price  Last Price  Close Price  ...  Day_Perc_Change  \
# 489     300.85      302.45       301.90  ...        -0.016612
# 490     298.65      300.60       300.65  ...        -0.004140
# 491     296.35      299.85       299.85  ...        -0.002661
# 492     296.90      297.15       297.75  ...        -0.007004
# 493     287.70      288.80       289.30  ...        -0.028380
#
#                    Trend  21_day_SMA  34_day_SMA  Trade_Call  \
# 489  Slight or No change  301.350000  299.379412           1
# ...

# %%
ax = plt.gca()

df.plot(kind='line',figsize = (20,10), x='Date', y='Average Price', ax=ax, color='yellow')
df.plot(kind='line',figsize = (20,10), x='Date', y='14_day_SMA', ax=ax, color='cyan')
df.plot(kind='line',figsize = (20,10), x='Date', y='14_day_bollinger_upper', ax=ax, color='blue', linestyle='--')
df.plot(kind='line',figsize = (20,10), x='Date', y='14_day_bollinger_lower', ax=ax, color='red', linestyle='--')


plt.title("14 day bollinger bands")
plt.ylabel("Average Price")
plt.show()

# %%
df.to_csv('week4.csv')
